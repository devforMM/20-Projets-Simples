# %%
from datetime import datetime

date = datetime.now().strftime("%Y/%m/%d")
# Out:
# 'y/m/d'

# %%
import json
data=[{
    "name":"amine",
    "age":24
}]

with open("exemple.json","w") as file:
    json.dump(data,file)

# %%
with open("exemple.jon","r") as file:
    data=json.load(file)


data.append({"product":"casque"})
with open ("exemple.json","w") as file:
    json.dump(data,file)

# %%
from datetime import datetime
# Out:
# datetime.datetime(2026, 9, 16, 17, 20, 30, 183534)
